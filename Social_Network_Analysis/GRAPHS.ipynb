# %%
import networkx as nx
import matplotlib.pyplot as plt
import networkx.drawing

def graph_create_dataset(graph_no):
    graph=[[]for i in range(graph_no)]
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/facebook.txt") as fp1:  
#         graph[0]=nx.Graph()
#         for line in fp1:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
    
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/hamster.txt") as fp2:
#         graph[0]=nx.Graph()
#         for line in fp2:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/hamster_full.txt") as fp3:
#         graph[0]=nx.Graph()
#         for line in fp3:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
    
    with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/google_plus.txt") as fp4:
        graph[0]=nx.Graph()
        for line in fp4:
            temp=line.split(" ")
            x=int(temp[0])
            y=int((temp[1].split("\n"))[0])
            graph[0].add_edges_from([(x,y)])
    
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/twitter.txt") as fp5:
#         graph[0]=nx.Graph()
#         for line in fp5:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/brightkite.txt") as fp6:  
#         graph[0]=nx.Graph()
#         for line in fp6:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/Epinions.txt") as fp7:
#         graph[0]=nx.Graph()
#         for line in fp7:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/facebook_wosn.txt") as fp8:
#         graph[0]=nx.Graph()
#         for line in fp8:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])

#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/slashdot.txt") as fp9:
#         graph[0]=nx.Graph()
#         for line in fp9:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/advogato.txt") as fp10:    
#         graph[0]=nx.Graph()
#         for line in fp10:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
##############   graphs not used ############

#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/gowalla.txt") as fp10:    
#         graph[0]=nx.Graph()
#         for line in fp10:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/livemocha.txt") as fp11:
#         graph[0]=nx.Graph()
#         for line in fp11:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[0].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/petster_cat.txt") as fp12:
#         graph[1]=nx.Graph()
#         for line in fp12:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[1].add_edges_from([(x,y)])
            
#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/hyves.txt") as fp13:
#         graph[2]=nx.Graph()
#         for line in fp13:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[2].add_edges_from([(x,y)])

#     with open("/home/sukanya/Desktop/jadavpur_internship/CODES/dataset/youtube.txt") as fp14:
#         graph[3]=nx.Graph()
#         for line in fp14:
#             temp=line.split(" ")
#             x=int(temp[0])
#             y=int((temp[1].split("\n"))[0])
#             graph[3].add_edges_from([(x,y)])
            
     #     nx.draw(graph[0],with_labels=True,node_size=50,font_size=8)
#     plt.show()
#     nx.draw(graph[1],with_labels=True,node_size=50,font_size=8)
#     plt.show()
#     nx.draw(graph[2],with_labels=True,node_size=50,font_size=8)
#     plt.show()
#     nx.draw(graph[3],with_labels=True,node_size=50,font_size=8)
#     plt.show()
#     nx.draw(graph[4],with_labels=True,node_size=50,font_size=8)
#     plt.show()
    
    return(graph)
           

if __name__=='__main__':
    graph_no=1
    graph=[[]for i in range(graph_no)]
    graph=graph_create_dataset(graph_no)
    
#     nx.draw(graph[0],with_labels=False,node_size=30)
#     plt.savefig("/home/sukanya/Desktop/jadavpur_internship/CODES/Networks/Graph_6.png")
#     plt.close()

    with open("/home/sukanya/Desktop/jadavpur_internship/CODES/Result.odt","a+") as sn:
        sn.write("\n")
        sn.write(" CORRELATION COEFFICIENT OF THE NETWORKS CONSIDERED ---------")
        sn.write("\n\n")
        for i in range(graph_no):
            corr_coeff=nx.degree_pearson_correlation_coefficient(graph[i])                         
            sn.write("Correlation Coefficient of Graph "+str(i+1)+" : "+str(corr_coeff))
            sn.write("\n")

#     for i in range(graph_no):
#         for j in range(len(graph[i])):
#             corr_coeff=nx.degree_pearson_correlation_coefficient(graph[i])
#             plt.title('CORRELATION_COEFFICIENT')
#             plt.plot(j,corr_coeff)
#             plt.ylabel('Correlation_coefficient')
#             plt.xlabel('Node')
#             plt.savefig("/home/sukanya/Desktop/jadavpur_internship/CODES/Correlation_Coefficifent/Graph_1.png")
#         plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d7e4a732e3a2> in <module>()
#     166             plt.ylabel('Correlation_coefficient')
#     167             plt.xlabel('Node')
# --> 168             plt.savefig("/home/sukanya/Desktop/jadavpur_internship/CODES/Correlation_Coefficifent/Graph_1.png")
#     169         plt.close()
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     699 def savefig(*args, **kwargs):
#     700     fig = gcf()
# --> 701     res = fig.savefig(*args, **kwargs)
#     702     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     703     return res
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2265                 orientation=orientation,
#    2266                 bbox_inches_restore=_bbox_inches_restore,
# -> 2267                 **kwargs)
#    2268         finally:
#    2269             if bbox_inches and restore_bbox:
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# /home/sukanya/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# KeyboardInterrupt:
